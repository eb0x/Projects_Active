# %%
### importing the libraries for TensorFlow
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Input, LSTM, Embedding, Dropout, Activation, Conv1D,GRU, Bidirectional, GlobalMaxPool1D 
from tensorflow.keras.models import Model,load_model, Sequential
from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorboard.plugins import projector

# %%
print('TensorFlow version is {}.'.format(tf.__version__))
if tf.test.gpu_device_name(): 
    print(f'Default GPU Device:  {tf.test.gpu_device_name()}')
else:
    print("Please install GPU version of TF")
# Out:
# TensorFlow version is 2.5.0.
# Default GPU Device:  /device:GPU:0

# %%
help("modules")
# Out:
# Please wait a moment while I gather a list of all available modules...
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-dr_y0fss because the default path (/.config/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.
# /usr/local/lib/python3.6/dist-packages/IPython/kernel/__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated since IPython 4.0.You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)
# /usr/lib/python3.6/pkgutil.py:92: MatplotlibDeprecationWarning:
# The matplotlib.compat module was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   __import__(info.name)
# Analyzer            bisect              keras               sched
# Crypto              bleach              keras_preprocessing scipy
# IPython             blis                keyring             secrets
# PIL                 builtins            keyword             secretstorage
# __future__          bz2                 kg_read             select
# _ast                cProfile            kiwisolver          selectors
# _asyncio            cached_property     lib2to3             send2trash
# _bisect             cachetools          linecache           setuptools
# _blake2             calendar            locale              shelve
# _bootlocale         catalogue           logging             shlex
# _bz2                certifi             lsb_release         shutil
# _cffi_backend       cffi                lzma                signal
# _codecs             cgi                 macpath             site
# _codecs_cn          cgitb               macurl2path         sitecustomize
# _codecs_hk          chardet             mailbox             six
# _codecs_iso2022     chunk               mailcap             sklearn
# _codecs_jp          cmath               markdown            smtpd
# _codecs_kr          cmd                 markupsafe          smtplib
# _codecs_tw          code                marshal             sndhdr
# _collections        codecs              math                socket
# _collections_abc    codeop              matplotlib          socketserver
# _compat_pickle      collections         mimetypes           softwareproperties
# _compression        colorsys            mistune             spacy
# _crypt              compileall          mmap                spwd
# _csv                concurrent          modulefinder        sqlite3
# _ctypes             configparser        multiprocessing     sre_compile
# _ctypes_test        contextlib          murmurhash          sre_constants
# _curses             copy                nbclient            sre_parse
# _curses_panel       copyreg             nbconvert           srsly
# _datetime           crypt               nbformat            ssl
# _dbm                cryptography        nest_asyncio        stat
# _dbus_bindings      csv                 netrc               statistics
# _dbus_glib_bindings ctypes              networkx            storemagic
# _decimal            curses              nis                 string
# _distutils_hack     cycler              nntplib             stringprep
# _dummy_thread       cymem               notebook            struct
# _elementtree        cythonmagic         ntpath              subprocess
# _functools          cytoolz             nturl2path          sunau
# _hashlib            dataclasses         numbers             symbol
# _heapq              datetime            numpy               sympyprinting
# _imp                dateutil            oauthlib            symtable
# _io                 dbm                 opcode              sys
# _json               dbus                operator            sysconfig
# _locale             decimal             opt_einsum          syslog
# _lsprof             decorator           optparse            tabnanny
# _lzma               defusedxml          os                  tarfile
# _markupbase         difflib             ossaudiodev         telnetlib
# _md5                dis                 packaging           tempfile
# _multibytecodec     distutils           pandas              tensorboard
# _multiprocessing    doctest             pandocfilters       tensorboard_data_server
# _opcode             dummy_threading     parser              tensorboard_plugin_wit
# _operator           easy_install        parso               tensorflow
# _osx_support        email               pasta               tensorflow_estimator
# _pickle             encodings           pathlib             termcolor
# _posixsubprocess    entrypoints         pdb                 terminado
# _pydecimal          enum                pexpect             termios
# _pyio               errno               pickle              test
# _pyrsistent_version faulthandler        pickleshare         testpath
# _random             fcntl               pickletools         tests
# _sha1               filecmp             pip                 textacy
# _sha256             fileinput           pipes               textwrap
# _sha3               flatbuffers         pkg_resources       thinc
# _sha512             fnmatch             pkgutil             this
# _signal             formatter           plac                threading
# _sitebuiltins       fractions           plac_core           threadpoolctl
# _socket             ftplib              plac_ext            time
# _sqlite3            functools           plac_tk             timeit
# _sre                gast                platform            tlz
# _ssl                gc                  plistlib            token
# _stat               genericpath         poplib              tokenize
# _string             getopt              posix               toolz
# _strptime           getpass             posixpath           tornado
# _struct             gettext             pprint              tqdm
# _symtable           gi                  preshed             trace
# _sysconfigdata_m_linux_x86_64-linux-gnu glob                profile             traceback
# _testbuffer         google_auth_oauthlib prometheus_client   tracemalloc
# _testcapi           grp                 prompt_toolkit      traitlets
# _testimportmultiple grpc                pstats              tty
# _testmultiphase     gzip                pty                 turtle
# _thread             h5py                ptyprocess          types
# _threading_local    hashlib             pvectorc            typing
# _tracemalloc        heapq               pwd                 typing_extensions
# _warnings           hmac                py_compile          unicodedata
# _weakref            html                pyasn1              unittest
# _weakrefset         http                pyasn1_modules      urllib
# abc                 idna                pyclbr              urllib3
# absl                imaplib             pycparser           uu
# aifc                imghdr              pydoc               uuid
# antigravity         imp                 pydoc_data          venv
# apt                 importlib           pyemd               warnings
# apt_inst            importlib_metadata  pyexpat             wasabi
# apt_pkg             imports             pygments            wave
# aptsources          inspect             pygtkcompat         wcwidth
# argon2              io                  pylab               weakref
# argparse            ipaddress           pyparsing           webbrowser
# array               ipykernel           pyphen              webencodings
# asn1crypto          ipykernel_launcher  pyrsistent          werkzeug
# ast                 ipython_genutils    pytz                wheel
# astunparse          ipywidgets          qtconsole           widgetsnbextension
# async_generator     itertools           qtpy                wrapt
# asynchat            jedi                queue               wsgiref
# asyncio             jellyfish           quopri              xdg
# asyncore            jinja2              random              xdrlib
# atexit              joblib              re                  xml
# attr                json                readline            xmlrpc
# audioop             jsonschema          reprlib             xxlimited
# autoreload          jupyter             requests            xxsubtype
# backcall            jupyter_client      requests_oauthlib   zipapp
# base64              jupyter_console     resource            zipfile
# bdb                 jupyter_core        rlcompleter         zipimport
# bin                 jupyter_http_over_ws rmagic              zipp
# binascii            jupyterlab_pygments rsa                 zlib
# binhex              jupyterlab_widgets  runpy               zmq
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose name or summary contain the string "spam".
# /usr/lib/python3.6/pkgutil.py:107: VisibleDeprecationWarning: zmq.eventloop.minitornado is deprecated in pyzmq 14.0 and will be removed.
#     Install tornado itself to use zmq with the tornado IOLoop.
#
#   yield from walk_packages(path, info.name+'.', onerror)

# %%
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
import numpy as np

n = 38607
d = 150
k = 4

# Generate data
X = np.random.randn(n, d)
Y = to_categorical(np.random.randint(k, size = n), k)

model = Sequential()
model.add(Dense(128, input_dim = d, activation = 'relu'))
model.add(Dense(64, activation = 'relu'))
model.add(Dense(4, activation = 'softmax'))
model.compile(
    loss = 'binary_crossentropy',
    optimizer='adam', metrics=['accuracy'])
model.summary()

model.fit(X, Y, epochs = 100, batch_size = 128, verbose = 1)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               19328
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 27,844
# Trainable params: 27,844
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 302/302 [==============================] - 2s 2ms/step - loss: 0.5746 - accuracy: 0.2543
# Epoch 2/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.5598 - accuracy: 0.2968
# Epoch 3/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.5533 - accuracy: 0.3307
# Epoch 4/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.5458 - accuracy: 0.3620
# Epoch 5/100
# 302/302 [==============================] - 1s 3ms/step - loss: 0.5367 - accuracy: 0.3902
# Epoch 6/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.5256 - accuracy: 0.4205
# Epoch 7/100
# 302/302 [==============================] - 1s 3ms/step - loss: 0.5137 - accuracy: 0.4416
# Epoch 8/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.5019 - accuracy: 0.4657
# Epoch 9/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.4903 - accuracy: 0.4866
# Epoch 10/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.4798 - accuracy: 0.5077
# Epoch 11/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.4707 - accuracy: 0.5196
# Epoch 12/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.4614 - accuracy: 0.5394
# Epoch 13/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.4525 - accuracy: 0.5560
# Epoch 14/100
# 302/302 [==============================] - 1s 3ms/step - loss: 0.4448 - accuracy: 0.5662
# Epoch 15/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.4374 - accuracy: 0.5795
# Epoch 16/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.4310 - accuracy: 0.5858
# Epoch 17/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.4247 - accuracy: 0.5975
# Epoch 18/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.4186 - accuracy: 0.6061
# Epoch 19/100
# 302/302 [==============================] - 1s 3ms/step - loss: 0.4136 - accuracy: 0.6129
# Epoch 20/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.4086 - accuracy: 0.6187
# Epoch 21/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.4032 - accuracy: 0.6279
# Epoch 22/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3990 - accuracy: 0.6374
# Epoch 23/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3946 - accuracy: 0.6408
# Epoch 24/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3907 - accuracy: 0.6477
# Epoch 25/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3866 - accuracy: 0.6524
# Epoch 26/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3836 - accuracy: 0.6571
# Epoch 27/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3800 - accuracy: 0.6603
# Epoch 28/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3765 - accuracy: 0.6653
# Epoch 29/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3733 - accuracy: 0.6691
# Epoch 30/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3700 - accuracy: 0.6737
# Epoch 31/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3671 - accuracy: 0.6798
# Epoch 32/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3647 - accuracy: 0.6808
# Epoch 33/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3616 - accuracy: 0.6858
# Epoch 34/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3597 - accuracy: 0.6880
# Epoch 35/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3574 - accuracy: 0.6916
# Epoch 36/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3542 - accuracy: 0.6957
# Epoch 37/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3522 - accuracy: 0.6985
# Epoch 38/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3496 - accuracy: 0.7005
# Epoch 39/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3477 - accuracy: 0.7033
# Epoch 40/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3453 - accuracy: 0.7071
# Epoch 41/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3439 - accuracy: 0.7066
# Epoch 42/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3417 - accuracy: 0.7135
# Epoch 43/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3399 - accuracy: 0.7137
# Epoch 44/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3373 - accuracy: 0.7180
# Epoch 45/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3359 - accuracy: 0.7213
# Epoch 46/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3343 - accuracy: 0.7223
# Epoch 47/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3329 - accuracy: 0.7247
# Epoch 48/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3310 - accuracy: 0.7262
# Epoch 49/100
# 302/302 [==============================] - 1s 3ms/step - loss: 0.3290 - accuracy: 0.7279
# Epoch 50/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3274 - accuracy: 0.7303
# Epoch 51/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3253 - accuracy: 0.7329
# Epoch 52/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3242 - accuracy: 0.7347
# Epoch 53/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3236 - accuracy: 0.7369
# Epoch 54/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3213 - accuracy: 0.7399
# Epoch 55/100
# 302/302 [==============================] - 1s 3ms/step - loss: 0.3201 - accuracy: 0.7405
# Epoch 56/100
# 302/302 [==============================] - 1s 3ms/step - loss: 0.3188 - accuracy: 0.7414
# Epoch 57/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3172 - accuracy: 0.7448
# Epoch 58/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3156 - accuracy: 0.7452
# Epoch 59/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3154 - accuracy: 0.7445
# Epoch 60/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3138 - accuracy: 0.7473
# Epoch 61/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3130 - accuracy: 0.7514
# Epoch 62/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3119 - accuracy: 0.7500
# Epoch 63/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3104 - accuracy: 0.7527
# Epoch 64/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3093 - accuracy: 0.7543
# Epoch 65/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3076 - accuracy: 0.7560
# Epoch 66/100
# 302/302 [==============================] - 1s 3ms/step - loss: 0.3076 - accuracy: 0.7560
# Epoch 67/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3055 - accuracy: 0.7584
# Epoch 68/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3046 - accuracy: 0.7591
# Epoch 69/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3042 - accuracy: 0.7613
# Epoch 70/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3027 - accuracy: 0.7618
# Epoch 71/100
# 302/302 [==============================] - 1s 3ms/step - loss: 0.3019 - accuracy: 0.7642
# Epoch 72/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3018 - accuracy: 0.7636
# Epoch 73/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3003 - accuracy: 0.7670
# Epoch 74/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.2992 - accuracy: 0.7652
# Epoch 75/100
# 302/302 [==============================] - 1s 3ms/step - loss: 0.2974 - accuracy: 0.7685
# Epoch 76/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.2971 - accuracy: 0.7671
# Epoch 77/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.2966 - accuracy: 0.7692
# Epoch 78/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.2952 - accuracy: 0.7720
# Epoch 79/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.2948 - accuracy: 0.7719
# Epoch 80/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.2942 - accuracy: 0.7718
# Epoch 81/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.2929 - accuracy: 0.7741
# Epoch 82/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.2927 - accuracy: 0.7734
# Epoch 83/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.2918 - accuracy: 0.7745
# Epoch 84/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.2906 - accuracy: 0.7781
# Epoch 85/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.2900 - accuracy: 0.7792
# Epoch 86/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.2888 - accuracy: 0.7792
# Epoch 87/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.2882 - accuracy: 0.7797
# Epoch 88/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.2875 - accuracy: 0.7794
# Epoch 89/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.2868 - accuracy: 0.7820
# Epoch 90/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.2857 - accuracy: 0.7811
# Epoch 91/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.2850 - accuracy: 0.7842
# Epoch 92/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.2848 - accuracy: 0.7857
# Epoch 93/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.2840 - accuracy: 0.7853
# Epoch 94/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.2828 - accuracy: 0.7852
# Epoch 95/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.2822 - accuracy: 0.7867
# Epoch 96/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.2817 - accuracy: 0.7872
# Epoch 97/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.2809 - accuracy: 0.7898
# Epoch 98/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.2809 - accuracy: 0.7885
# Epoch 99/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.2791 - accuracy: 0.7918
# Epoch 100/100
# 302/302 [==============================] - 1s 2ms/step - loss: 0.2791 - accuracy: 0.7900
